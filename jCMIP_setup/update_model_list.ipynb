# %%
# %load_ext autoreload
# %autoreload 2

import jCMIP as jc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# %%
CMIP6list = '../CMIP6list'
jc.generateList('6',CMIP6list)

CMIP5list = '../CMIP5list'
jc.generateList('5',CMIP5list)
# Out:
# starting models on list: 105
# total models on list: 105
# starting models on list: 60
# total models on list: 60

# %%
# Add notes to models:

# CMIP5
Clist = jc.readList(CMIP5list) 
jc.updateList(CMIP5list,Model='CCSM4'            ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),
                                                          '22/06/08 - duplicate tas files in some rcps',])
jc.updateList(CMIP5list,Model='CESM1-BGC'        ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='CESM1-CAM5'       ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='CESM1-CAM5-1-FV2' ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='CESM1-FASTCHEM'   ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='CESM1-WACCM'      ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='CFSv2-2011'       ,notes=[('21/10/18 - ocean data flipped up-down'),
                                                         ('21/10/13 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/18 - ocean mask does not seem right'),
                                                         ('21/10/18 - assumed A-grid'),])
jc.updateList(CMIP5list,Model='CNRM-CM5'         ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),])
jc.updateList(CMIP5list,Model='CNRM-CM5-2'       ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),])
jc.updateList(CMIP5list,Model='CSIRO-Mk3-6-0'    ,notes=[('22/05/17 - temperature masked incorrectly at high lat. 0C?'),])
jc.updateList(CMIP5list,Model='CanAM4'           ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='CanCM4'           ,notes=[('21/10/13 - unusually deep ocean along coast and north pole'),])
jc.updateList(CMIP5list,Model='CanESM2'          ,notes=[('21/10/13 - unusually deep ocean along coast and north pole'),
                                                         ('22/05/17 - thetao in K not degrees C'),
                                                         ('22/05/17 - something odd about volcello (upsidedown, but not)'),])
jc.updateList(CMIP5list,Model='EC-EARTH'         ,notes=[('21/10/14 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/14 - no mask is defined for ocean data, estimated mask from data'),
                                                         ('21/10/14 - ocean grid determined from masks'),
                                                         ('22/05/18 - volcello is full of errors, no depths below layer 11'),
                                                         ('22/06/08 - duplicate tas files (nc & nc4) in r12i1p1'),])
jc.updateList(CMIP5list,Model='FGOALS-s2'        ,notes=[('21/10/14 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/14 - ocean grid determined from masks'),
                                                         ('21/10/14 - problems with computation of ocean depths along coast'),])
jc.updateList(CMIP5list,Model='FGOALS-gl'        ,notes=[('21/10/18 - ocean data flipped up-down'),
                                                         ('21/10/18 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/18 - ocean grid determined from masks'),])
jc.updateList(CMIP5list,Model='FGOALS-g2'        ,notes=[('21/10/19 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/19 - ocean grid same for t/u/v'),])
jc.updateList(CMIP5list,Model='FIO-ESM'          ,notes=[('21/10/14 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/14 - ocean grid determined from masks'),
                                                         ('21/12/22 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='GEOS-5'           ,notes=[('21/10/19 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/19 - ocean grid same for t/u/v'),
                                                         ('21/10/19 - ocean lon_bnds oddly defined at 180'),])
jc.updateList(CMIP5list,Model='GFDL-ESM2G'       ,notes=[('21/12/22 - mask and depths do not line up'),])
jc.updateList(CMIP5list,Model='GFDL-HIRAM-C180'  ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='GFDL-HIRAM-C360'  ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='GISS-E2-H'        ,notes=[('21/10/14 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/14 - ocean grid determined from masks'),
                                                         ('21/12/22 - mask and depths do not line up'),
                                                         ('22/05/18 - some levels not masked properly, used values to mask'),])
jc.updateList(CMIP5list,Model='GISS-E2-H-CC'     ,notes=[('21/10/14 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/14 - ocean grid determined from masks'),
                                                         ('21/12/22 - mask and depths do not line up'),
                                                         ('22/05/18 - some levels not masked properly, used values to mask'),])
jc.updateList(CMIP5list,Model='GISS-E2-R'        ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='GISS-E2-R-CC'     ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP5list,Model='HadGEM2-A'        ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='HadGEM2-AO'       ,notes=[('21/10/18 - ocean data flipped up-down'),])
jc.updateList(CMIP5list,Model='IPSL-CM5A-LR'     ,notes=[('21/10/14 - ocean depth is incorrect'),])
jc.updateList(CMIP5list,Model='IPSL-CM5A-MR'     ,notes=[('21/10/14 - ocean depth is incorrect'),])
jc.updateList(CMIP5list,Model='IPSL-CM5B-LR'     ,notes=[('21/10/14 - ocean depth is incorrect'),])
jc.updateList(CMIP5list,Model='MIROC-ESM'        ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),
                                                         ('21/10/14 - not completely z-level'),
                                                         ('23/03/13 - values at bottom of ocean at high latitudes'),])
jc.updateList(CMIP5list,Model='MIROC-ESM-CHEM'   ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),
                                                         ('21/10/14 - not completely z-level'),
                                                         ('23/03/13 - values at bottom of ocean at high latitudes'),])
jc.updateList(CMIP5list,Model='MIROC5'           ,notes=[('21/10/14 - no mask is defined for ocean data, estimated mask from data'),
                                                         ('21/10/14 - not completely z-level'),
                                                         ('21/12/22 - some grid unmasked points with 0 depth'),
                                                         ('23/03/13 - values at bottom of ocean at high latitudes'),])
jc.updateList(CMIP5list,Model='MIROC4h'          ,notes=[('21/10/18 - ocean mask does not seem right'),
                                                         ('21/10/18 - no mask is defined for ocean data, estimated mask from data'),
                                                         ('21/10/18 - not completely z-level'),
                                                         ('21/10/21 - rcp45 data only goes until 2035'),])
jc.updateList(CMIP5list,Model='MPI-ESM-LR'       ,notes=[('21/10/14 - odd deep points along coast'),
                                                         ('21/12/22 - some grid unmasked points with 0 depth'),])
jc.updateList(CMIP5list,Model='MPI-ESM-MR'       ,notes=[('21/10/14 - odd deep points along coast'),])
jc.updateList(CMIP5list,Model='MPI-ESM-P'        ,notes=[('21/10/14 - odd deep points along coast'),
                                                         ('21/12/22 - some grid unmasked points with 0 depth'),])
jc.updateList(CMIP5list,Model='MRI-AGCM3-2H'     ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='MRI-AGCM3-2S'     ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='MRI-CGCM3'        ,notes=[('21/10/14 - known issue with bottom ocean depth, fixed not included'),])
jc.updateList(CMIP5list,Model='MRI-ESM1'         ,notes=[('21/10/14 - no mask is defined for ocean data, estimated mask from data'),])
jc.updateList(CMIP5list,Model='NICAM-09'         ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP5list,Model='NorESM1-M'        ,notes=[('22/05/13 - volcello has thicknesses'),])
jc.updateList(CMIP5list,Model='NorESM1-ME'       ,notes=[('22/05/13 - volcello has thicknesses'),])
jc.updateList(CMIP5list,Model='bcc-csm1-1'       ,notes=[('21/10/14 - odd ocean depths'),])
jc.updateList(CMIP5list,Model='bcc-csm1-1-m'     ,notes=[('21/10/14 - odd ocean depths'),])
jc.updateList(CMIP5list,Model='inmcm4'           ,notes=[('21/10/14 - ocean not on z-levels'),])


# CMIP6
Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='ACCESS-OM2'       ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),])
jc.updateList(CMIP6list,Model='ACCESS-OM2-025'   ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),
                                                         ('21/10/13 - problem with western boundary ocean lon/lat values'),])
jc.updateList(CMIP6list,Model='AWI-CM-1-1-HR'    ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='AWI-CM-1-1-LR'    ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='BCC-CSM2-MR'      ,notes=[('21/10/13 - unusually deep Arctic ocean'),])
jc.updateList(CMIP6list,Model='BCC-ESM1'         ,notes=[('21/10/13 - unusually deep Arctic ocean'),])
jc.updateList(CMIP6list,Model='CAS-ESM2-0'       ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),
                                                         ('22/01/21 - areacello mask shifted by 1 grid point in longitude'),])
jc.updateList(CMIP6list,Model='CESM1-CAM5-SE-HR' ,notes=[('21/10/13 - strange/partial ocean grid'),
                                                         ('21/10/19 - difficulties/cannot define ocean grid'),
                                                         ('21/12/17 - ocean mask makes it difficult to define basin masks'),])
jc.updateList(CMIP6list,Model='CESM1-CAM5-SE-LR' ,notes=[('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CESM2'            ,notes=[('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CESM2-FV2'        ,notes=[('21/10/13 - some ocean lat/lon over land masked'),
                                                         ('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CESM2-WACCM'      ,notes=[('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CESM2-WACCM-FV2'  ,notes=[('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CIESM'            ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),
                                                         ('21/12/16 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CNRM-CM6-1-HR'    ,notes=[('21/10/15 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='CanESM5-CanOE'    ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='E3SM-1-0'         ,notes=[('22/01/05 - ocean data on gr grid'),])
jc.updateList(CMIP6list,Model='E3SM-1-1'         ,notes=[('22/01/05 - ocean data on gr grid'),])
jc.updateList(CMIP6list,Model='E3SM-1-1-ECA'     ,notes=[('22/01/05 - ocean data on gr grid'),])
jc.updateList(CMIP6list,Model='EC-Earth3'        ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3-AerChem',notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3-CC'     ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3-LR'     ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='EC-Earth3-Veg'    ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3-Veg-LR' ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),
                                                         ('22/06/08 - missing years in tas data for r1i1p1f1'),])
jc.updateList(CMIP6list,Model='EC-Earth3P'       ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3P-HR'    ,notes=[('21/10/17 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='EC-Earth3P-VHR'   ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='FGOALS-f3-H'      ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='FGOALS-f3-L'      ,notes=[('21/10/13 - change in ocean resolution at ~25N'),])
jc.updateList(CMIP6list,Model='FGOALS-g3'        ,notes=[('21/10/13 - change in ocean resolution at ~25N'),])
jc.updateList(CMIP6list,Model='FIO-ESM-2-0'      ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='GFDL-AM4'         ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='GFDL-CM4'         ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),
                                                         ('21/12/16 - ocean grid need to be revisited'),])
jc.updateList(CMIP6list,Model='GFDL-CM4C192'     ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='GFDL-ESM4'        ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='GFDL-OM4p5B'      ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='GISS-E2-1-G'      ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='GISS-E2-1-G-CC'   ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='GISS-E2-1-H'      ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='GISS-E2-2-G'      ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='GISS-E2-2-H'      ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='HadGEM3-GC31-LM'  ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='HiRAM-SIT-HR'     ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='HiRAM-SIT-LR'     ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='IITM-ESM'         ,notes=[('21/10/13 - ocean t/u/v points same lat/lon') ,
                                                         ('21/10/13 - ocean grid determined from masks'),])
jc.updateList(CMIP6list,Model='INM-CM4-8'        ,notes=[('21/10/21 - ocean data in gr1'),
                                                         ('21/10/21 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/21 - a few odd points over Siberia and at coast in ocean mask'),])
jc.updateList(CMIP6list,Model='INM-CM5-0'        ,notes=[('21/10/21 - ocean data in gr1'),
                                                         ('21/10/21 - ocean t/u/v points same lat/lon'),])
jc.updateList(CMIP6list,Model='INM-CM5-H'        ,notes=[('21/10/21 - ocean data in gr1'),
                                                         ('21/10/21 - ocean t/u/v points same lat/lon'),])
jc.updateList(CMIP6list,Model='IPSL-CM5A2-INCA'  ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR'     ,notes=[('21/12/16 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR-INCA',notes=[('21/12/16 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='IPSL-CM6A-ATM-HR' ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='KACE-1-0-G'       ,notes=[('22/01/05 - incomplete ocean data'),
                                                         ('22/01/05 - ocean data on gr grid'),])
jc.updateList(CMIP6list,Model='KIOST-ESM'        ,notes=[('22/01/05 - ocean data on gr1 grid'),
                                                         ('22/01/05 - unclear model grid, no meshmask made'),])
jc.updateList(CMIP6list,Model='MIROC-ES2L'       ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),
                                                         ('21/10/18 - not completely z-level'),
                                                         ('21/12/16 - unmasked grid points in bottom depth'),])
jc.updateList(CMIP6list,Model='MIROC-ES2H'       ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='MIROC6'           ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),
                                                         ('21/10/18 - not completely z-level'),
                                                         ('21/12/16 - unmasked grid points in bottom depth'),
                                                         ('21/12/16 - some grid unmasked points with 0 depth'),])
jc.updateList(CMIP6list,Model='MRI-AGCM3-2-H'    ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='MRI-AGCM3-2-S'    ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='MRI-ESM2-0'       ,notes=[('21/12/16 - unmasked grid points in bottom depth'),
                                                         ('21/12/16 - some grid unmasked points with 0 depth'),])
jc.updateList(CMIP6list,Model='NICAM16-7S'       ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='NICAM16-8S'       ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='NICAM16-9S'       ,notes=[('21/10/19 - no ocean data'),])
jc.updateList(CMIP6list,Model='NorCPM1'          ,notes=[('21/10/13 - ocean grid computed from regridded data (gr)'),
                                                         ('22/05/17 - historical r1i1p1f1 starts 2015 for vo'),])
jc.updateList(CMIP6list,Model='NorESM1-F'        ,notes=[('21/10/13 - incomplete ocean data'),])
jc.updateList(CMIP6list,Model='NorESM2-LM'       ,notes=[('21/10/13 - ocean grid computed from regridded data (gr)'),])
jc.updateList(CMIP6list,Model='NorESM2-MM'       ,notes=[('21/10/13 - ocean grid computed from regridded data (gr)'),])
jc.updateList(CMIP6list,Model='SAM0-UNICON'      ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='TaiESM1'          ,notes=[('21/10/18 - ocean u/v points with 0 velocity are included in mask'),])
jc.updateList(CMIP6list,Model='TaiESM1-TIMCOM'   ,notes=[('21/10/19 - ocean t/u/v points same lat/lon'),
                                                         ('21/10/19 - ocean grid similar for t/u/v'),
                                                         ('21/10/19 - ocean grid assumed A-grid'),])
jc.updateList(CMIP6list,Model='UKESM1-0-LL'      ,notes=[('22/02/28 - r13i1p1f2 does not have halo points removed'),])

# %%
#### Add save directory to all models (where masks and stuff are stored):
savedir = '/gws/pw/j07/wishbone/jmecki/'
jc.updateAllList(CMIP6list,savedir=(savedir + 'CMIP6/'))
jc.updateAllList(CMIP5list,savedir=(savedir + 'CMIP5/'))

# %%
# Add data directory to all models:
datadir5 = '/badc/cmip5/data/cmip5/output1/'
jc.updateAllList(CMIP5list,datadir=datadir5)
datadir6 = '/badc/cmip6/data/CMIP6/'
jc.updateAllList(CMIP6list,datadir=datadir6)

# %%
# Models without lon/lat properly defined:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='CFSv2-2011'    ,Ogrid='A'  )     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='CNRM-CM5'      ,Ogrid='Ctr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='CNRM-CM5-2'    ,Ogrid='Ctr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='EC-EARTH'      ,Ogrid='Ctr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='FGOALS-s2'     ,Ogrid='Bbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='FGOALS-gl'     ,Ogrid='Bbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='FGOALS-g2'     ,Ogrid='A'  )     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='FIO-ESM'       ,Ogrid='Btr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='GISS-E2-H'     ,Ogrid='Bbr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='GISS-E2-H-CC'  ,Ogrid='Bbr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP5list,Model='GEOS-5'        ,Ogrid='A'  )     # incorrect lon/lat on u and v point

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='ACCESS-OM2'    ,Ogrid='Btr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='ACCESS-OM2-025',Ogrid='Btr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='AWI-CM-1-1-MR' ,Ogrid='Unstructured')
jc.updateList(CMIP6list,Model='AWI-ESM-1-1-LR',Ogrid='Unstructured')
jc.updateList(CMIP6list,Model='CAS-ESM2-0'    ,Ogrid='Bbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='CIESM'         ,Ogrid='Btr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='E3SM-1-0'      ,Ogrid='A-gr')    # using regridded data
jc.updateList(CMIP6list,Model='E3SM-1-1'      ,Ogrid='A-gr')    # using regridded data
jc.updateList(CMIP6list,Model='E3SM-1-1-ECA'  ,Ogrid='A-gr')    # using regridded data
jc.updateList(CMIP6list,Model='GFDL-CM4'      ,Ogrid='Cbl')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='ICON-ESM-LR'   ,Ogrid='Unstructured')
jc.updateList(CMIP6list,Model='IITM-ESM'      ,Ogrid='Btr')     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='INM-CM4-8'     ,Ogrid='A-gr1')   # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='INM-CM5-0'     ,Ogrid='A-gr1')   # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='INM-CM5-H'     ,Ogrid='A-gr1')   # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='NorCPM1'       ,Ogrid='Cbl-gr')  # density coordinates, using regridded data
jc.updateList(CMIP6list,Model='NorESM2-LM'    ,Ogrid='Cbl-gr')  # density coordinates, using regridded data
jc.updateList(CMIP6list,Model='NorESM2-MM'    ,Ogrid='Cbl-gr')  # density coordinates, using regridded data
jc.updateList(CMIP6list,Model='TaiESM1-TIMCOM',Ogrid='A'  )     # incorrect lon/lat on u and v point
jc.updateList(CMIP6list,Model='UKESM1-1-LL'   ,Ogrid='Ctr'  )   # incorrect lon/lat on u point - using UKESM1-0-LL

# %%
# Models with periodic points:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='CMCC-CESM'        ,OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP5list,Model='CMCC-CM'          ,OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP5list,Model='CMCC-CMS'         ,OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP5list,Model='CNRM-CM5'         ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='CNRM-CM5-2'       ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='EC-EARTH'         ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='IPSL-CM5A-LR'     ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='IPSL-CM5A-MR'     ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='IPSL-CM5B-LR'     ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='MPI-ESM-LR'       ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='MPI-ESM-MR'       ,OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP5list,Model='MPI-ESM-P'        ,OextraWE=[1,1])  # remove halo points

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='CMCC-CM2-HR4' ,    OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CMCC-CM2-SR5' ,    OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CMCC-CM2-VHR4',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='CMCC-ESM2',        OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CNRM-CM6-1',       OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='CNRM-CM6-1-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='CNRM-ESM2-1',      OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3',        OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-AerChem',OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-CC',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-Veg',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3-Veg-LR', OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3P',       OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='EC-Earth3P-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-HR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-LR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='ECMWF-IFS-MR',     OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM5A2-INCA',  OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR',     OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='IPSL-CM6A-LR-INCA',OextraWE=[1,1])  # Masked values on edges of grid, remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM-1-2-HAM',  OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-HR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-LR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='MPI-ESM1-2-XR',    OextraWE=[1,1])  # remove halo points
jc.updateList(CMIP6list,Model='NESM3',            OextraWE=[1,1])  # remove halo points

# %%
# Flipped N-S:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='MPI-ESM-LR'     ,OflipNS=True)
jc.updateList(CMIP5list,Model='MPI-ESM-MR'     ,OflipNS=True)
jc.updateList(CMIP5list,Model='MPI-ESM-P'      ,OflipNS=True)


Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='FGOALS-f3-L',    OflipNS=True)
jc.updateList(CMIP6list,Model='FGOALS-g3',      OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM-1-2-HAM',OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-HR',  OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-LR',  OflipNS=True)
jc.updateList(CMIP6list,Model='MPI-ESM1-2-XR',  OflipNS=True)

# %%
# Extra T points:

Clist = jc.readList(CMIP5list)
jc.updateList(CMIP5list,Model='HadCM3',    OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-AO',OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-CC',OextraT=True)
jc.updateList(CMIP5list,Model='HadGEM2-ES',OextraT=True)

Clist = jc.readList(CMIP6list)
jc.updateList(CMIP6list,Model='MRI-ESM2-0',OextraT=True)

# %%
# Models with mesh_mask computed:

Clist = jc.readList(CMIP5list)
Models = list(Clist.keys())
for mm in Models:
    Model = Clist[mm]
    mmfile = (Model.savedir + 'mesh_masks/' + Model.name + '_mesh_mask.nc')
    if os.path.exists(mmfile):
        jc.updateList(CMIP5list,Model=Model.name,Omeshmask=mmfile)
    else:
        jc.updateList(CMIP5list,Model=Model.name,Omeshmask='unknown')
        
Clist = jc.readList(CMIP6list)
Models = list(Clist.keys())
for mm in Models:
    Model = Clist[mm]
    mmfile = (Model.savedir + 'mesh_masks/' + Model.name + '_mesh_mask.nc')
    if os.path.exists(mmfile):
        jc.updateList(CMIP6list,Model=Model.name,Omeshmask=mmfile)
    else:
        jc.updateList(CMIP6list,Model=Model.name,Omeshmask='unknown')

# %%
# Determine lon/lat, regular and grid (Ocean):

filename = CMIP6list
#filename = CMIP5list
Clist = jc.readList(filename)
Models = list(Clist.keys())

var  = 'thetao'
var2 = 'tos'

for mm in Models:
    # Check model data:
    Model = Clist[mm]
    print(mm)
    
    # Determine lon/lat:
    if Model.Olon == 'unknown':
        if ((Model.name == 'INM-CM4-8') | (Model.name == 'INM-CM5-0') | (Model.name == 'INM-CM5-H') |
            (Model.name == 'KIOST-ESM')):
            Files = Model.getFiles(var=var,gtype='gr1')
        elif ((Model.name[0:4] == 'E3SM')):
            Files = Model.getFiles(var=var,gtype='gr')
        else:
            Files = Model.getFiles(var=var)
        nf = len(Files)
        print(nf)
        if (nf != 0):
            ncid = Dataset(Files[0],'r')
            klist = list(ncid.variables.keys())
            ncid.close()

            print(klist)
            
            for ll in range(0,len(klist)):
                if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                    nlat = ll
                if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                    nlon = ll

            jc.updateList(filename,Model.name,Olat=klist[nlat])
            jc.updateList(filename,Model.name,Olon=klist[nlon])

            ncid = Dataset(Files[0],'r')
            lon = ncid.variables[klist[nlon]][:]
            ncid.close()
            nd = np.squeeze((np.shape(np.shape(lon))))
            print(np.shape(lon))

            if nd == 2:
                jc.updateList(filename,Model.name,Oreg=False)
            elif nd == 1:
                jc.updateList(filename,Model.name,Oreg=True)
        else:
            if ((Model.name == 'KACE-1-0-G')):
                Files = Model.getFiles(var=var2,gtype='gr')
            else:
                Files = Model.getFiles(var=var2)
                
            nf = len(Files)
            print(nf)
            if (nf != 0):
                ncid = Dataset(Files[0],'r')
                klist = list(ncid.variables.keys())
                ncid.close()

                print(klist)

                for ll in range(0,len(klist)):
                    if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                        nlat = ll
                    if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                        nlon = ll

                jc.updateList(filename,Model.name,Olat=klist[nlat])
                jc.updateList(filename,Model.name,Olon=klist[nlon])

                ncid = Dataset(Files[0],'r')
                lon = ncid.variables[klist[nlon]][:]
                ncid.close()
                nd = np.squeeze((np.shape(np.shape(lon))))
                print(np.shape(lon))

                if nd == 2:
                    jc.updateList(filename,Model.name,Oreg=False)
                elif nd == 1:
                    jc.updateList(filename,Model.name,Oreg=True)

    Clist = jc.readList(filename)
    print(Clist[mm].Olon)
    print(Clist[mm].Olat)
    print(Clist[mm].Oreg)
    
    # Determine model grid:
    Model = Clist[mm]
    if ((Model.Ogrid == 'unknown')):
        # Find Files:
        so = Model.getFiles(var='so',EXP='*',ENS='*',vtype='Omon',gtype='gn')
        vo = Model.getFiles(var='vo',EXP='*',ENS='*',vtype='Omon',gtype='gn')
        uo = Model.getFiles(var='uo',EXP='*',ENS='*',vtype='Omon',gtype='gn')
    
        if ((len(so) != 0) & (len(vo) != 0) | (len(uo) != 0)):
            # Find mask, lat and lon:
            Tlon,Tlat = jc.Olatlon(Model,so[0],'so')
            Ulon,Ulat = jc.Olatlon(Model,uo[0],'uo')
            Vlon,Vlat = jc.Olatlon(Model,vo[0],'vo')
            
            if Model.Oreg:
                Tlon,Tlat = np.meshgrid(Tlon,Tlat)
                Vlon,Vlat = np.meshgrid(Vlon,Vlat)
                Ulon,Ulat = np.meshgrid(Ulon,Ulat)

            # Determine model grid:
            TmV_lat = Tlat[:,:]-Vlat[:,:]
            TmV_lon = Tlon[:,:]-Vlon[:,:]
            # -- => Btr
            # ++ => Bbl
            # -+ => Btl
            # -0 => Ct?
            # +0 => Cb?
            TmU_lat = Tlat[:,:]-Ulat[:,:]
            TmU_lon = Tlon[:,:]-Ulon[:,:]
            # -- => Btr
            # ++ => Bbl
            # -+ => Btl
            # 0- => C?r
            # 0+ => C?l
            VmU_lat = Vlat[:,:]-Ulat[:,:]
            VmU_lon = Vlon[:,:]-Ulon[:,:]
            # 00 => B
            # +- => Ctr
            # -- => Cbr
            # -+ => Cbl
            
            lims = 0.00001

            nn_TmV_lat = [np.sum(TmV_lat > lims), np.sum(np.abs(TmV_lat) <= lims), np.sum(TmV_lat < -lims)]
            nn_TmV_lon = [np.sum(TmV_lon > lims), np.sum(np.abs(TmV_lon) <= lims), np.sum(TmV_lon < -lims)]
            nn_TmU_lat = [np.sum(TmU_lat > lims), np.sum(np.abs(TmU_lat) <= lims), np.sum(TmU_lat < -lims)]
            nn_TmU_lon = [np.sum(TmU_lon > lims), np.sum(np.abs(TmU_lon) <= lims), np.sum(TmU_lon < -lims)]
            nn_VmU_lat = [np.sum(VmU_lat > lims), np.sum(np.abs(VmU_lat) <= lims), np.sum(VmU_lat < -lims)]
            nn_VmU_lon = [np.sum(VmU_lon > lims), np.sum(np.abs(VmU_lon) <= lims), np.sum(VmU_lon < -lims)]
            
            print('VmU lat: ' + str(nn_VmU_lat) + ', VmU lon: ' + str(nn_VmU_lon))
            print('TmU lat: ' + str(nn_TmU_lat) + ', TmU lon: ' + str(nn_TmU_lon))
            print('TmV lat: ' + str(nn_TmV_lat) + ', TmV lon: ' + str(nn_TmV_lon))
            
            if not (((np.argmax(nn_VmU_lat) == 1) & (np.argmax(nn_VmU_lon) == 1))):
                if ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmU_lon) == 2)):
                    grid = 'Ctr'   
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmU_lon) == 0)):
                    grid = 'Cbl'  
                elif ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmU_lon) == 0)):
                    grid = 'Ctl'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmU_lon) == 2)):
                    grid = 'Cbr'
                else:
                    print('something has gone wrong')
            else:
                if ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmV_lon) == 2)):
                    grid = 'Btr'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmV_lon) == 0)):
                    grid = 'Bbl'
                elif ((np.argmax(nn_TmV_lat) == 2) & (np.argmax(nn_TmV_lon) == 0)):
                    grid = 'Btl'
                elif ((np.argmax(nn_TmV_lat) == 0) & (np.argmax(nn_TmV_lon) == 2)):
                    grid = 'Bbr'
                else:
                    grid = 'unknown'
                    print('need to double check grid')

            jc.updateList(filename,Model.name,Ogrid=grid)

    Clist = jc.readList(filename)
    print(Clist[mm].Ogrid)

# %%
# Determine lon/lat, regular and grid (Atmosphere):

filename = CMIP6list
#filename = CMIP5list
Clist = jc.readList(filename)
Models = list(Clist.keys())

var  = 'tas'
var2 = 'psl'

for mm in Models:
    # Check model data:
    Model = Clist[mm]
    print(mm)
    
    # Determine lon/lat:
    if Model.Alon == 'unknown':
        Files = Model.getFiles(var=var,vtype='Amon')
        nf = len(Files)
        
        if (nf == 0):
            Files = Model.getFiles(var=var,vtype='Amon',gtype='gr')
            nf = len(Files)
        
        if (nf == 0):
            Files = Model.getFiles(var=var,vtype='Amon',gtype='gr1')
            nf = len(Files)

        if (nf != 0):
            ncid = Dataset(Files[0],'r')
            klist = list(ncid.variables.keys())
            ncid.close()

            print(klist)
            
            for ll in range(0,len(klist)):
                if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                    nlat = ll
                if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                    nlon = ll

            jc.updateList(filename,Model.name,Alat=klist[nlat])
            jc.updateList(filename,Model.name,Alon=klist[nlon])

            ncid = Dataset(Files[0],'r')
            lon = ncid.variables[klist[nlon]][:]
            ncid.close()
            nd = np.squeeze((np.shape(np.shape(lon))))
            print(np.shape(lon))

            if nd == 2:
                jc.updateList(filename,Model.name,Areg=False)
            elif nd == 1:
                jc.updateList(filename,Model.name,Areg=True)
        else:
            Files = Model.getFiles(var=var2)
            nf = len(Files)
            print(nf)
            if (nf != 0):
                ncid = Dataset(Files[0],'r')
                klist = list(ncid.variables.keys())
                ncid.close()

                print(klist)

                for ll in range(0,len(klist)):
                    if ((klist[ll] == 'lat') | (klist[ll] == 'latitude') | (klist[ll] == 'nav_lat')):
                        nlat = ll
                    if ((klist[ll] == 'lon') | (klist[ll] == 'longitude') | (klist[ll] == 'nav_lon')):
                        nlon = ll

                jc.updateList(filename,Model.name,Alat=klist[nlat])
                jc.updateList(filename,Model.name,Alon=klist[nlon])

                ncid = Dataset(Files[0],'r')
                lon = ncid.variables[klist[nlon]][:]
                ncid.close()
                nd = np.squeeze((np.shape(np.shape(lon))))
                print(np.shape(lon))

                if nd == 2:
                    jc.updateList(filename,Model.name,Areg=False)
                elif nd == 1:
                    jc.updateList(filename,Model.name,Areg=True)
            

    Clist = jc.readList(filename)
    print(Clist[mm].Alon)
    print(Clist[mm].Alat)
    print(Clist[mm].Areg)

# %%
# Print model table:
sp1 = ','
sp2 = ':'

Clist = jc.readList(CMIP6list)

Models = list(Clist.keys())
for mm in Models[:]:
    model = Clist[mm]
    pline = (model.name + sp1)
    
    inst = model.getInstitute()
    ni = len(inst)
    for ii in range(0,ni-1):
        pline = (pline + inst[ii] + sp2)
    pline = (pline + inst[-1] + sp1)
    
    pline = (pline + model.Ogrid + sp1)
    
    so = model.getFiles(var='so',EXP='*',ENS='*',vtype='Omon',gtype='gn')
    if len(so) != 0:
        dmins = jc.getDims(so[0],'so')
        if model.Ogrid == 'Unstructured':
            pline = (pline + str(dmins[-1].size) + 'x' + str(dmins[-2].size) + sp1)
        else:
            pline = (pline + str(dmins[-1].size) + 'x' + str(dmins[-2].size) + 'x' + str(dmins[-3].size) + sp1)
    else:
        pline = (pline + sp1)
        
    pline = (pline + model.Omeshmask + sp1)
    
    notes = model.notes
    ni = len(notes)
    for ii in range(0,ni):
        pline = (pline + notes[ii] + sp2)
    pline = (pline + sp1)
        
    print(pline)

# %%
mName = 'IPSL-CM6A-LR-INCA'
fName = '../CMIP6list'
jc.updateList(fName,mName,Alat='unknown')
jc.updateList(fName,mName,Alon='unknown')

# %%
Model = Clist['KACE-1-0-G']
Files = Model.getFiles(var='tos',gtype='*')
Files
